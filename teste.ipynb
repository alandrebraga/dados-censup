# %%
from pyarrow import csv
import polars as pl
import os
import pyarrow.dataset as ds
import pyarrow as pa
import pyarrow.parquet as pq
import pandas as pd
from sqlalchemy import create_engine

# %%
connection_uri = "postgresql://postgres:admin@localhost/censo"
engine = create_engine(connection_uri)

# %%
engine
# Out:
# Engine(postgresql://postgres:***@localhost/censo)

# %%
df = pl.read_parquet('data/curso.parquet')
df.write_database(table_name='curso', connection=connection_uri, engine="sqlalchemy" )

# %%
pq.read_schema('data/curso.parquet')
# Out:
# NU_ANO_CENSO: int64
# NO_REGIAO: large_string
# CO_REGIAO: int64
# NO_UF: large_string
# SG_UF: large_string
# CO_UF: int64
# NO_MUNICIPIO: large_string
# CO_MUNICIPIO: int64
# IN_CAPITAL: int64
# TP_DIMENSAO: int64
# TP_ORGANIZACAO_ACADEMICA: int64
# TP_CATEGORIA_ADMINISTRATIVA: int64
# TP_REDE: int64
# CO_IES: int64
# NO_CURSO: large_string
# CO_CURSO: int64
# NO_CINE_ROTULO: large_string
# CO_CINE_ROTULO: large_string
# CO_CINE_AREA_GERAL: int64
# NO_CINE_AREA_GERAL: large_string
# CO_CINE_AREA_ESPECIFICA: int64
# NO_CINE_AREA_ESPECIFICA: large_string
# CO_CINE_AREA_DETALHADA: int64
# NO_CINE_AREA_DETALHADA: large_string
# TP_GRAU_ACADEMICO: int64
# IN_GRATUITO: int64
# TP_MODALIDADE_ENSINO: int64
# TP_NIVEL_ACADEMICO: int64
# QT_CURSO: int64
# QT_VG_TOTAL: int64
# QT_VG_TOTAL_DIURNO: int64
# QT_VG_TOTAL_NOTURNO: int64
# QT_VG_TOTAL_EAD: int64
# QT_VG_NOVA: int64
# QT_VG_PROC_SELETIVO: int64
# QT_VG_REMANESC: int64
# QT_VG_PROG_ESPECIAL: int64
# QT_INSCRITO_TOTAL: int64
# QT_INSCRITO_TOTAL_DIURNO: int64
# QT_INSCRITO_TOTAL_NOTURNO: int64
# QT_INSCRITO_TOTAL_EAD: int64
# QT_INSC_VG_NOVA: int64
# QT_INSC_PROC_SELETIVO: int64
# QT_INSC_VG_REMANESC: int64
# QT_INSC_VG_PROG_ESPECIAL: int64
# QT_ING: int64
# QT_ING_FEM: int64
# QT_ING_MASC: int64
# QT_ING_DIURNO: int64
# QT_ING_NOTURNO: int64
# QT_ING_VG_NOVA: int64
# QT_ING_VESTIBULAR: int64
# QT_ING_ENEM: int64
# QT_ING_AVALIACAO_SERIADA: int64
# QT_ING_SELECAO_SIMPLIFICA: int64
# QT_ING_EGR: int64
# QT_ING_OUTRO_TIPO_SELECAO: int64
# QT_ING_PROC_SELETIVO: int64
# QT_ING_VG_REMANESC: int64
# QT_ING_VG_PROG_ESPECIAL: int64
# QT_ING_OUTRA_FORMA: int64
# QT_ING_0_17: int64
# QT_ING_18_24: int64
# QT_ING_25_29: int64
# QT_ING_30_34: int64
# QT_ING_35_39: int64
# QT_ING_40_49: int64
# QT_ING_50_59: int64
# QT_ING_60_MAIS: int64
# QT_ING_BRANCA: int64
# QT_ING_PRETA: int64
# QT_ING_PARDA: int64
# QT_ING_AMARELA: int64
# QT_ING_INDIGENA: int64
# QT_ING_CORND: int64
# QT_MAT: int64
# QT_MAT_FEM: int64
# QT_MAT_MASC: int64
# QT_MAT_DIURNO: int64
# QT_MAT_NOTURNO: int64
# QT_MAT_0_17: int64
# QT_MAT_18_24: int64
# QT_MAT_25_29: int64
# QT_MAT_30_34: int64
# QT_MAT_35_39: int64
# QT_MAT_40_49: int64
# QT_MAT_50_59: int64
# QT_MAT_60_MAIS: int64
# QT_MAT_BRANCA: int64
# QT_MAT_PRETA: int64
# QT_MAT_PARDA: int64
# QT_MAT_AMARELA: int64
# QT_MAT_INDIGENA: int64
# QT_MAT_CORND: int64
# QT_CONC: int64
# QT_CONC_FEM: int64
# QT_CONC_MASC: int64
# QT_CONC_DIURNO: int64
# QT_CONC_NOTURNO: int64
# QT_CONC_0_17: int64
# QT_CONC_18_24: int64
# QT_CONC_25_29: int64
# QT_CONC_30_34: int64
# QT_CONC_35_39: int64
# QT_CONC_40_49: int64
# QT_CONC_50_59: int64
# QT_CONC_60_MAIS: int64
# QT_CONC_BRANCA: int64
# QT_CONC_PRETA: int64
# QT_CONC_PARDA: int64
# QT_CONC_AMARELA: int64
# QT_CONC_INDIGENA: int64
# QT_CONC_CORND: int64
# QT_ING_NACBRAS: int64
# QT_ING_NACESTRANG: int64
# QT_MAT_NACBRAS: int64
# QT_MAT_NACESTRANG: int64
# QT_CONC_NACBRAS: int64
# QT_CONC_NACESTRANG: int64
# QT_ALUNO_DEFICIENTE: int64
# QT_ING_DEFICIENTE: int64
# QT_MAT_DEFICIENTE: int64
# QT_CONC_DEFICIENTE: int64
# QT_ING_FINANC: int64
# QT_ING_FINANC_REEMB: int64
# QT_ING_FIES: int64
# QT_ING_RPFIES: int64
# QT_ING_FINANC_REEMB_OUTROS: int64
# QT_ING_FINANC_NREEMB: int64
# QT_ING_PROUNII: int64
# QT_ING_PROUNIP: int64
# QT_ING_NRPFIES: int64
# QT_ING_FINANC_NREEMB_OUTROS: int64
# QT_MAT_FINANC: int64
# QT_MAT_FINANC_REEMB: int64
# QT_MAT_FIES: int64
# QT_MAT_RPFIES: int64
# QT_MAT_FINANC_REEMB_OUTROS: int64
# QT_MAT_FINANC_NREEMB: int64
# QT_MAT_PROUNII: int64
# QT_MAT_PROUNIP: int64
# QT_MAT_NRPFIES: int64
# QT_MAT_FINANC_NREEMB_OUTROS: int64
# QT_CONC_FINANC: int64
# QT_CONC_FINANC_REEMB: int64
# QT_CONC_FIES: int64
# QT_CONC_RPFIES: int64
# QT_CONC_FINANC_REEMB_OUTROS: int64
# QT_CONC_FINANC_NREEMB: int64
# QT_CONC_PROUNII: int64
# QT_CONC_PROUNIP: int64
# QT_CONC_NRPFIES: int64
# QT_CONC_FINANC_NREEMB_OUTROS: int64
# QT_ING_RESERVA_VAGA: int64
# QT_ING_RVREDEPUBLICA: int64
# QT_ING_RVETNICO: int64
# QT_ING_RVPDEF: int64
# QT_ING_RVSOCIAL_RF: int64
# QT_ING_RVOUTROS: int64
# QT_MAT_RESERVA_VAGA: int64
# QT_MAT_RVREDEPUBLICA: int64
# QT_MAT_RVETNICO: int64
# QT_MAT_RVPDEF: int64
# QT_MAT_RVSOCIAL_RF: int64
# QT_MAT_RVOUTROS: int64
# QT_CONC_RESERVA_VAGA: int64
# QT_CONC_RVREDEPUBLICA: int64
# QT_CONC_RVETNICO: int64
# QT_CONC_RVPDEF: int64
# QT_CONC_RVSOCIAL_RF: int64
# QT_CONC_RVOUTROS: int64
# QT_SIT_TRANCADA: int64
# QT_SIT_DESVINCULADO: int64
# QT_SIT_TRANSFERIDO: int64
# QT_SIT_FALECIDO: int64
# QT_ING_PROCESCPUBLICA: int64
# QT_ING_PROCESCPRIVADA: int64
# QT_ING_PROCNAOINFORMADA: int64
# QT_MAT_PROCESCPUBLICA: int64
# QT_MAT_PROCESCPRIVADA: int64
# QT_MAT_PROCNAOINFORMADA: int64
# QT_CONC_PROCESCPUBLICA: int64
# QT_CONC_PROCESCPRIVADA: int64
# QT_CONC_PROCNAOINFORMADA: int64
# QT_PARFOR: int64
# QT_ING_PARFOR: int64
# QT_MAT_PARFOR: int64
# QT_CONC_PARFOR: int64
# QT_APOIO_SOCIAL: int64
# QT_ING_APOIO_SOCIAL: int64
# QT_MAT_APOIO_SOCIAL: int64
# QT_CONC_APOIO_SOCIAL: int64
# QT_ATIV_EXTRACURRICULAR: int64
# QT_ING_ATIV_EXTRACURRICULAR: int64
# QT_MAT_ATIV_EXTRACURRICULAR: int64
# QT_CONC_ATIV_EXTRACURRICULAR: int64
# QT_MOB_ACADEMICA: int64
# QT_ING_MOB_ACADEMICA: int64
# QT_MAT_MOB_ACADEMICA: int64
# QT_CONC_MOB_ACADEMICA: int64
# CO_CINE_ROTULO2: large_string
